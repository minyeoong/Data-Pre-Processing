# %% [markdown]
# ## FbProhet
# - 시계열분석
# - 참고 링크 : https://www.facebook.com/gpa/facebook-protect

# %%
# import necessary libraries
import numpy as np 
from prophet import Prophet
from prophet.plot import plot_plotly, plot_components_plotly
from prophet.diagnostics import cross_validation
from prophet.diagnostics import performance_metrics
import warnings
warnings.filterwarnings('ignore')  
warnings.simplefilter(action = "ignore", category = RuntimeWarning)
import datetime as dt
import pandas as pd
pd.core.common.is_list_like = pd.api.types.is_list_like
import pandas_datareader.data as web
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.dates as mdates
import pandas as pd
#from plotnine import *
import io
# to predictive A
import statistics as st
# %matplotlib inline
import matplotlib.dates as mdates
from pandas import DataFrame
from pandas import to_datetime
from statsmodels.tsa.stattools import kpss
from statsmodels.tsa.stattools import adfuller
from  sklearn.metrics import mean_absolute_error
# Out:
# Importing plotly failed. Interactive plots will not work.

# %%
df = pd.read_csv('sales_data.csv', encoding='unicode_escape')

# %%
df
# Out:
#        ï»¿InvoiceNo StockCode                          Description  Quantity  \
# 0            536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1            536365     71053                  WHITE METAL LANTERN         6
# 2            536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3            536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4            536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...             ...       ...                                  ...       ...
# 541904       581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905       581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906       581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907       581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908       581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 0        12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1        12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2        12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3        12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4        12/1/2010 8:26       3.39     17850.0  United Kingdom
# ...                 ...        ...         ...             ...
# 541904  12/9/2011 12:50       0.85     12680.0          France
# 541905  12/9/2011 12:50       2.10     12680.0          France
# 541906  12/9/2011 12:50       4.15     12680.0          France
# 541907  12/9/2011 12:50       4.15     12680.0          France
# 541908  12/9/2011 12:50       4.95     12680.0          France
#
# [541909 rows x 8 columns]

# %%
pd.to_datetime(df['InvoiceDate'])
# Out:
# 0        2010-12-01 08:26:00
# 1        2010-12-01 08:26:00
# 2        2010-12-01 08:26:00
# 3        2010-12-01 08:26:00
# 4        2010-12-01 08:26:00
#                  ...
# 541904   2011-12-09 12:50:00
# 541905   2011-12-09 12:50:00
# 541906   2011-12-09 12:50:00
# 541907   2011-12-09 12:50:00
# 541908   2011-12-09 12:50:00
# Name: InvoiceDate, Length: 541909, dtype: datetime64[ns]

# %%
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])

# %% [markdown]
# ### sales data _ 총 주문을  예측해 보자!

# %%
df_1 = df.copy()

# %%
df_1 = df_1[df_1.Quantity>0]

# %%
df_1 =df_1[df_1.UnitPrice>0]

# %%
df_1['Q_price'] = df_1['Quantity']*df_1['UnitPrice']

# %%
df_1
# Out:
#        ï»¿InvoiceNo StockCode                          Description  Quantity  \
# 0            536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1            536365     71053                  WHITE METAL LANTERN         6
# 2            536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3            536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4            536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...             ...       ...                                  ...       ...
# 541904       581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905       581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906       581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907       581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908       581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country  Q_price
# 0      2010-12-01 08:26:00       2.55     17850.0  United Kingdom    15.30
# 1      2010-12-01 08:26:00       3.39     17850.0  United Kingdom    20.34
# 2      2010-12-01 08:26:00       2.75     17850.0  United Kingdom    22.00
# 3      2010-12-01 08:26:00       3.39     17850.0  United Kingdom    20.34
# 4      2010-12-01 08:26:00       3.39     17850.0  United Kingdom    20.34
# ...                    ...        ...         ...             ...      ...
# 541904 2011-12-09 12:50:00       0.85     12680.0          France    10.20
# 541905 2011-12-09 12:50:00       2.10     12680.0          France    12.60
# 541906 2011-12-09 12:50:00       4.15     12680.0          France    16.60
# 541907 2011-12-09 12:50:00       4.15     12680.0          France    16.60
# 541908 2011-12-09 12:50:00       4.95     12680.0          France    14.85
#
# [530104 rows x 9 columns]

# %%
df_1= df_1[['InvoiceDate','Q_price']] # 두 가지 변수로만 가지고 시계열을 예측한다!

# %%
##프로펫은 컬럼의 이름을 바꿔줘야 한다!
# 필수과정 
# 시계열값은 ds, 예측값(내가 예측하고 싶은 값, y) y

df_1.rename(columns={'InvoiceDate':'ds','Q_price':'y'},inplace=True)

# %%
df_1
# Out:
#                         ds      y
# 0      2010-12-01 08:26:00  15.30
# 1      2010-12-01 08:26:00  20.34
# 2      2010-12-01 08:26:00  22.00
# 3      2010-12-01 08:26:00  20.34
# 4      2010-12-01 08:26:00  20.34
# ...                    ...    ...
# 541904 2011-12-09 12:50:00  10.20
# 541905 2011-12-09 12:50:00  12.60
# 541906 2011-12-09 12:50:00  16.60
# 541907 2011-12-09 12:50:00  16.60
# 541908 2011-12-09 12:50:00  14.85
#
# [530104 rows x 2 columns]

# %%
df_1.y.plot()
# Out:
# <AxesSubplot: >

# %%
df_1=df_1.set_index('ds')

# %%
df_1
# Out:
#                          y
# ds
# 2010-12-01 08:26:00  15.30
# 2010-12-01 08:26:00  20.34
# 2010-12-01 08:26:00  22.00
# 2010-12-01 08:26:00  20.34
# 2010-12-01 08:26:00  20.34
# ...                    ...
# 2011-12-09 12:50:00  10.20
# 2011-12-09 12:50:00  12.60
# 2011-12-09 12:50:00  16.60
# 2011-12-09 12:50:00  16.60
# 2011-12-09 12:50:00  14.85
#
# [530104 rows x 1 columns]

# %%
df_2 = df_1.resample('D').sum()

# %%
df_2
# Out:
#                     y
# ds
# 2010-12-01   58960.79
# 2010-12-02   47748.38
# 2010-12-03   46943.71
# 2010-12-04       0.00
# 2010-12-05   31774.95
# ...               ...
# 2011-12-05   88741.96
# 2011-12-06   56713.21
# 2011-12-07   75439.16
# 2011-12-08   82495.00
# 2011-12-09  200920.60
#
# [374 rows x 1 columns]

# %%
df_2.reset_index(inplace=True)

# %%
df_2 #인덱스를 풀어야한다.
# Out:
#             ds          y
# 0   2010-12-01   58960.79
# 1   2010-12-02   47748.38
# 2   2010-12-03   46943.71
# 3   2010-12-04       0.00
# 4   2010-12-05   31774.95
# ..         ...        ...
# 369 2011-12-05   88741.96
# 370 2011-12-06   56713.21
# 371 2011-12-07   75439.16
# 372 2011-12-08   82495.00
# 373 2011-12-09  200920.60
#
# [374 rows x 2 columns]

# %%
# train, test 나눠야 한다.
train = df_2[:270]
test = df_2[270:]

# %%
train
# Out:
#             ds         y
# 0   2010-12-01  58960.79
# 1   2010-12-02  47748.38
# 2   2010-12-03  46943.71
# 3   2010-12-04      0.00
# 4   2010-12-05  31774.95
# ..         ...       ...
# 265 2011-08-23  25993.68
# 266 2011-08-24  49035.36
# 267 2011-08-25  23827.46
# 268 2011-08-26  25626.44
# 269 2011-08-27      0.00
#
# [270 rows x 2 columns]

# %%
test
# Out:
#             ds          y
# 270 2011-08-28   10805.03
# 271 2011-08-29       0.00
# 272 2011-08-30   31866.31
# 273 2011-08-31   25380.17
# 274 2011-09-01   37370.15
# ..         ...        ...
# 369 2011-12-05   88741.96
# 370 2011-12-06   56713.21
# 371 2011-12-07   75439.16
# 372 2011-12-08   82495.00
# 373 2011-12-09  200920.60
#
# [104 rows x 2 columns]

# %%
## 프로펫으로 시계열 분석을 진행해보자!
prophet = Prophet(daily_seasonality = True,
                 growth='linear')

prophet.fit(train)
# Out:
# 18:04:45 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:45 - cmdstanpy - INFO - Chain [1] done processing

# %%
future =prophet.make_future_dataframe(periods=30) #뒤에 얼마나 예측할 것인가?
forecast = prophet.predict(future)

# %%
forecast[['ds','yhat']][270:300] #실제 프로펫이 예측한 값
# Out:
#             ds          yhat
# 270 2011-08-28  13509.852832
# 271 2011-08-29  27022.042971
# 272 2011-08-30  38181.552276
# 273 2011-08-31  29599.391329
# 274 2011-09-01  36322.642334
# 275 2011-09-02  26807.217254
# 276 2011-09-03   1641.211790
# 277 2011-09-04  13630.964601
# 278 2011-09-05  27143.154741
# 279 2011-09-06  38302.664045
# 280 2011-09-07  29720.503098
# 281 2011-09-08  36443.754103
# 282 2011-09-09  26928.329024
# 283 2011-09-10   1762.323559
# 284 2011-09-11  13752.076370
# 285 2011-09-12  27264.266510
# 286 2011-09-13  38423.775814
# 287 2011-09-14  29841.614868
# 288 2011-09-15  36564.865872
# 289 2011-09-16  27049.440793
# 290 2011-09-17   1883.435328
# 291 2011-09-18  13873.188139
# 292 2011-09-19  27385.378279
# 293 2011-09-20  38544.887584
# 294 2011-09-21  29962.726637
# 295 2011-09-22  36685.977642
# 296 2011-09-23  27170.552562
# 297 2011-09-24   2004.547098
# 298 2011-09-25  13994.299909
# 299 2011-09-26  27506.490049

# %%
df_2[270:300]
# Out:
#             ds           y
# 270 2011-08-28   10805.030
# 271 2011-08-29       0.000
# 272 2011-08-30   31866.310
# 273 2011-08-31   25380.170
# 274 2011-09-01   37370.150
# 275 2011-09-02   42322.020
# 276 2011-09-03       0.000
# 277 2011-09-04   17119.590
# 278 2011-09-05   37157.140
# 279 2011-09-06   28349.910
# 280 2011-09-07   34413.530
# 281 2011-09-08   27195.800
# 282 2011-09-09   30075.620
# 283 2011-09-10       0.000
# 284 2011-09-11   35511.670
# 285 2011-09-12   29738.330
# 286 2011-09-13   55117.050
# 287 2011-09-14   23592.980
# 288 2011-09-15   78218.950
# 289 2011-09-16   27724.220
# 290 2011-09-17       0.000
# 291 2011-09-18   15745.730
# 292 2011-09-19   49269.880
# 293 2011-09-20  109612.030
# 294 2011-09-21   48560.680
# 295 2011-09-22   59354.790
# 296 2011-09-23   40601.750
# 297 2011-09-24       0.000
# 298 2011-09-25   31372.661
# 299 2011-09-26   29335.171

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12,6))
plt.plot(forecast['yhat'], label='Data1')
plt.plot(df_2['y'], label='Data2')
plt.xlabel('Date')
plt.ylabel('Value')
plt.title('Comparison of Data1 and Data2')
plt.legend()
plt.show()
